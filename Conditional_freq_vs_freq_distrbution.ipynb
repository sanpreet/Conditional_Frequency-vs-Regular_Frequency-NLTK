# %%
import nltk

# %%
a = [('Pens','Rotomax'),('Pens','Parker'),('Pens','Mont Blanc'),('Pencil','Active Pen'),('Pencil','C. Howard Hunt')]

# %%
a
# Out:
# [('Pens', 'Rotomax'),
#  ('Pens', 'Parker'),
#  ('Pens', 'Mont Blanc'),
#  ('Pencil', 'Active Pen'),
#  ('Pencil', 'C. Howard Hunt')]

# %%
f = nltk.FreqDist(a)

# %%
c = nltk.ConditionalFreqDist(a)

# %%
c
# Out:
# <ConditionalFreqDist with 2 conditions>

# %%
for i in c:
    print i
# Out:
# Pencil
# Pens

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
c.plot()

# %%
f.plot()
